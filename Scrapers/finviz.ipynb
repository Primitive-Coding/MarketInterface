# %%
from finviz import Finviz

finviz = Finviz()

# %% [markdown]
# # Financial Statements
#
# - Income Statement
# - Balance Sheet
# - Cash Flow
#
# All statements will be saved locally, to reduce future queries.

# %%
inc = finviz.get_income_statement("TSSI")

data = inc.loc[["Revenue", "COGs", "Gross Profit", "Net Income", "Gross Margin", "Revenue_Growth", "Earnings_Growth"]]
data
# Out:
#                 12/31/2017 12/31/2018 12/31/2019 12/31/2020  12/31/2021  \
# index
# Revenue              18.32      22.34      32.78      45.06       27.41
# COGs                 11.07      14.24      26.56      38.79       21.59
# Gross Profit          7.24       8.10       6.22       6.27        5.83
# Net Income            0.77       2.44       0.13       0.08       -1.30
# Gross Margin         39.55      36.26      18.98      13.92       21.25
# Revenue_Growth         NaN     21.94%     46.73%     37.46%     -39.17%
# Earnings_Growth        NaN    216.88%    -94.67%    -38.46%  -1,725.00%
#
#                 12/31/2022 12/31/2023        TTM
# index
# Revenue              30.64      54.40     122.53
# COGs                 22.04      43.72     104.59
# Gross Profit          8.60      10.68      17.93
# Net Income           -0.07       0.07       4.40
# Gross Margin         28.06      19.63      14.64
# Revenue_Growth      11.78%     77.55%    125.24%
# ...

# %%
inc = finviz.get_income_statement("NVDA")
inc
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[3], line 1
# ----> 1 inc = finviz.get_income_statement("NVDA")
#       2 inc
#
# File m:\Coding\Python\Markets\MarketInterface\Scrapers\finviz.py:61, in Finviz.get_income_statement(self, ticker, include_period_length)
#      59     df.drop("Period Length", axis=0, inplace=True)
#      60 df = df.rename(index=income_statement_mapping)
# ---> 61 df.loc["Revenue_Growth"] = self._calc_growth(df.loc["Revenue"].to_list())
#      62 df.loc["Earnings_Growth"] = self._calc_growth(df.loc["Net Income"].to_list())
#      63 return df
#
# File m:\Coding\Python\Markets\MarketInterface\Scrapers\finviz.py:261, in Finviz._calc_growth(self, values, return_as_percent)
#     259 else:
#     260     v2 = values[index - 1]
# --> 261     v, v2 = float(v), float(v2)
#     262     g = (v - v2) / abs(v2)
#     263     if return_as_percent:
#
# ...
